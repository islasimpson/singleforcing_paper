# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from math import nan

from CASutils import averaging_utils as avg

# %%
plotpath='/project/cas/islas/python_plots/singleforcing_paper/figures/supplemental/'

# %%
ghgs2 = xr.open_dataset("/project/cas/islas/python_savs/singleforcing_paper/DATA_SORT/FORCINGS/GHGs.nc")
ghgs1 = xr.open_dataset("/project/cas/islas/python_savs/singleforcing_paper/DATA_SORT/FORCINGS/GHGs_LENS1.nc")
bmb2 = xr.open_dataset("/project/cas/islas/python_savs/singleforcing_paper/DATA_SORT/FORCINGS/BMB.nc")
bmb1 = xr.open_dataset("/project/cas/islas/python_savs/singleforcing_paper/DATA_SORT/FORCINGS/BMB_LENS1.nc")
bmb2_cmip6 = xr.open_dataset("/project/cas/islas/python_savs/singleforcing_paper/DATA_SORT/FORCINGS/BMB_standard.nc")
aer2 = xr.open_dataset("/project/cas/islas/python_savs/singleforcing_paper/DATA_SORT/FORCINGS/AAER.nc")
aer1 = xr.open_dataset("/project/cas/islas/python_savs/singleforcing_paper/DATA_SORT/FORCINGS/AAER_LENS1.nc")

# %%
fig = plt.figure(figsize=(16,16))

ax = fig.add_axes([0.0,0.8,0.25,0.17])
ax.set_xlim(1850,2050)
ax.set_title('(a) Biomass burning black carbon', fontsize=16)
ax.set_xticks([1850,1900,1950,2000,2050])
ax.set_xticklabels(['1850','1900','1950','2000','2050'], fontsize=14)
ax.set_yticks([1.6,1.8,2.0,2.2,2.4,2.6,2.8])
ax.set_yticklabels(['1.6','1.8','2.0','2.2','2.4','2.6','2.8'], fontsize=14)
ax.set_ylabel('Emissions (Tg/year)', fontsize=14)

ax.plot(bmb2.year, bmb2.bmb_bc, color='maroon', linewidth=2, label='LENS2-SF')
ax.plot(bmb2_cmip6.year, bmb2_cmip6.bmb_bc, color='lightcoral', linewidth=2, linestyle='dotted', label='CMIP6')
ax.plot(bmb1.year, bmb1.bmb_bc, color='teal', linewidth=2, label='LENS1')

ax.legend()


ax = fig.add_axes([0.32,0.8,0.25,0.17])
ax.set_xlim(1850,2050)
ax.set_title('(b) Biomass burning SO4', fontsize=16)
ax.set_xticks([1850,1900,1950,2000,2050])
ax.set_xticklabels(['1850','1900','1950','2000','2050'], fontsize=14)
ax.set_ylabel('Emissions (Tg/year)', fontsize=14)
ax.set_yticks([0.08,0.10,0.12,0.14,0.16,0.18])
ax.set_yticklabels(['0.08','0.10','0.12','0.14','0.16','0.18'], fontsize=14)

ax.plot(bmb2.year, bmb2.bmb_so4, color='maroon', linewidth=2, label='LENS2-SF')
ax.plot(bmb2_cmip6.year, bmb2_cmip6.bmb_so4, color='lightcoral', linewidth=2, linestyle='dotted', label='CMIP6')
ax.plot(bmb1.year, bmb1.bmb_so4, color='teal', linewidth=2, label='LENS1')

ax.legend()


ax = fig.add_axes([0.64,0.8,0.25,0.17])
ax.set_xlim(1850,2050)
ax.set_title('(c) Biomass burning SO2', fontsize=16)
ax.set_xticks([1850,1900,1950,2000,2050])
ax.set_xticklabels(['1850','1900','1950','2000','2050'], fontsize=14)
ax.set_yticks([1.7,2,2.3,2.6,2.9,3.2,3.5,3.8])
ax.set_yticklabels(['1.7','2.0','2.3','2.6','2.9','3.2','3.5','3.8'], fontsize=14)
ax.set_ylabel('Emissions (Tg/year)', fontsize=14)


ax.plot(bmb2.year, bmb2.bmb_so2, color='maroon', linewidth=2, label='LENS2-SF')
ax.plot(bmb2_cmip6.year, bmb2_cmip6.bmb_so2, color='lightcoral', linewidth=2, linestyle='dotted', label='CMIP6')
ax.plot(bmb1.year, bmb1.bmb_so2, color='teal', linewidth=2, label='LENS1')

ax.legend()


ax = fig.add_axes([0.16,0.57,0.25,0.17])
ax.set_xlim(1850,2050)
ax.set_title('(d) Biomass burning POM', fontsize=16)
ax.set_xticks([1850,1900,1950,2000,2050])
ax.set_xticklabels(['1850','1900','1950','2000','2050'], fontsize=14)
ax.set_ylim(12,35)
ax.set_yticks([15,20,25,30,35])
ax.set_yticklabels(['15','20','25','30','35'], fontsize=14)

ax.set_ylabel('Emissions (Tg/year)', fontsize=14)

ax.plot(bmb2.year, bmb2.bmb_pom, color='maroon', linewidth=2, label='LENS2-SF')
ax.plot(bmb2_cmip6.year, bmb2_cmip6.bmb_pom, color='lightcoral', linewidth=2, linestyle='dotted', label='CMIP6')
ax.plot(bmb1.year, bmb1.bmb_pom, color='teal', linewidth=2, label='LENS1')

ax.legend(loc='upper left')


ax = fig.add_axes([0.48,0.57,0.25,0.17])
ax.set_xlim(1850,2050)
ax.set_title('(e) Biomass burning SOAG', fontsize=16)
ax.set_xticks([1850,1900,1950,2000,2050])
ax.set_xticklabels(['1850','1900','1950','2000','2050'], fontsize=14)
ax.set_ylim(0.6,2.4)
ax.set_yticks([0.6,1,1.4,1.8,2.2])
ax.set_yticklabels(['0.6','1.0','1.4','1.8','2.2'], fontsize=14)

ax.set_ylabel('Emissions (Tg/year)', fontsize=14)

ax.plot(bmb2.year, bmb2.bmb_soag, color='maroon', linewidth=2, label='LENS2-SF')
ax.plot(bmb2_cmip6.year, bmb2_cmip6.bmb_soag, color='lightcoral', linewidth=2, linestyle='dotted', label='CMIP6')

ax.legend(loc='upper left')

fig.savefig(plotpath+'figS1.png', bbox_inches='tight', facecolor='white')
fig.savefig(plotpath+'figS1.pdf', bbox_inches='tight', facecolor='white')
